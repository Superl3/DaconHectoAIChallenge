# %%
import argparse
import cv2
import glob
import numpy as np
from collections import OrderedDict
import os
import torch
import requests

from models.network_swinir import SwinIR as net
from utils import util_calculate_psnr_ssim as util

from PIL import Image

# %%
import shutil

# --- 출력 디렉토리 초기화 함수 ---
def initialize_output_root(path):
    """
    지정된 출력 루트 디렉토리를 초기화합니다.
    디렉토리가 이미 존재하면 삭제하고, 다시 생성합니다.
    """
    if os.path.exists(path):
        print(f"Output root directory '{path}' already exists. Deleting its content...")
        try:
            shutil.rmtree(path) # 디렉토리와 그 안의 모든 내용을 삭제
            print(f"Directory '{path}' deleted successfully.")
        except OSError as e:
            print(f"Error: Could not remove directory '{path}'. {e}")
            print("Please check directory permissions or if it's in use.")
            return False # 삭제 실패 시 False 반환
    
    try:
        os.makedirs(path, exist_ok=True) # 디렉토리가 존재하지 않으면 생성 (삭제 후이므로 항상 새로 생성)
        print(f"Directory '{path}' created successfully.")
        return True # 성공 시 True 반환
    except OSError as e:
        print(f"Error: Could not create directory '{path}'. {e}")
        return False # 생성 실패 시 False 반환

# %%
def define_model(args):
    # 001 classical image sr
    if args.task == 'classical_sr':
        model = net(upscale=args.scale, in_chans=3, img_size=args.training_patch_size, window_size=8,
                    img_range=1., depths=[6, 6, 6, 6, 6, 6], embed_dim=180, num_heads=[6, 6, 6, 6, 6, 6],
                    mlp_ratio=2, upsampler='pixelshuffle', resi_connection='1conv')
        param_key_g = 'params'

    # 002 lightweight image sr
    # use 'pixelshuffledirect' to save parameters   
    elif args.task == 'lightweight_sr':
        model = net(upscale=args.scale, in_chans=3, img_size=64, window_size=8,
                    img_range=1., depths=[6, 6, 6, 6], embed_dim=60, num_heads=[6, 6, 6, 6],
                    mlp_ratio=2, upsampler='pixelshuffledirect', resi_connection='1conv')
        param_key_g = 'params'

    # 003 real-world image sr
    elif args.task == 'real_sr':
        if not args.large_model:
            # use 'nearest+conv' to avoid block artifacts
            model = net(upscale=args.scale, in_chans=3, img_size=64, window_size=8,
                        img_range=1., depths=[6, 6, 6, 6, 6, 6], embed_dim=180, num_heads=[6, 6, 6, 6, 6, 6],
                        mlp_ratio=2, upsampler='nearest+conv', resi_connection='1conv')
        else:
            # larger model size; use '3conv' to save parameters and memory; use ema for GAN training
            model = net(upscale=args.scale, in_chans=3, img_size=64, window_size=8,
                        img_range=1., depths=[6, 6, 6, 6, 6, 6, 6, 6, 6], embed_dim=240,
                        num_heads=[8, 8, 8, 8, 8, 8, 8, 8, 8],
                        mlp_ratio=2, upsampler='nearest+conv', resi_connection='3conv')
        param_key_g = 'params_ema'

    # 004 grayscale image denoising
    elif args.task == 'gray_dn':
        model = net(upscale=1, in_chans=1, img_size=128, window_size=8,
                    img_range=1., depths=[6, 6, 6, 6, 6, 6], embed_dim=180, num_heads=[6, 6, 6, 6, 6, 6],
                    mlp_ratio=2, upsampler='', resi_connection='1conv')
        param_key_g = 'params'

    # 005 color image denoising
    elif args.task == 'color_dn':
        model = net(upscale=1, in_chans=3, img_size=128, window_size=8,
                    img_range=1., depths=[6, 6, 6, 6, 6, 6], embed_dim=180, num_heads=[6, 6, 6, 6, 6, 6],
                    mlp_ratio=2, upsampler='', resi_connection='1conv')
        param_key_g = 'params'

    # 006 grayscale JPEG compression artifact reduction
    # use window_size=7 because JPEG encoding uses 8x8; use img_range=255 because it's sligtly better than 1
    elif args.task == 'jpeg_car':
        model = net(upscale=1, in_chans=1, img_size=126, window_size=7,
                    img_range=255., depths=[6, 6, 6, 6, 6, 6], embed_dim=180, num_heads=[6, 6, 6, 6, 6, 6],
                    mlp_ratio=2, upsampler='', resi_connection='1conv')
        param_key_g = 'params'

    # 006 color JPEG compression artifact reduction
    # use window_size=7 because JPEG encoding uses 8x8; use img_range=255 because it's sligtly better than 1
    elif args.task == 'color_jpeg_car':
        model = net(upscale=1, in_chans=3, img_size=126, window_size=7,
                    img_range=255., depths=[6, 6, 6, 6, 6, 6], embed_dim=180, num_heads=[6, 6, 6, 6, 6, 6],
                    mlp_ratio=2, upsampler='', resi_connection='1conv')
        param_key_g = 'params'
        
    pretrained_model = torch.load(args.model_path, map_location=torch.device('cpu')) 
    model.load_state_dict(pretrained_model[param_key_g] if param_key_g in pretrained_model.keys() else pretrained_model, strict=True)
    return model

# %%
def setup(args):
    # 001 classical image sr/ 002 lightweight image sr
    if args.task in ['classical_sr', 'lightweight_sr']:
        save_dir = f'results/swinir_{args.task}_x{args.scale}'
        folder = args.folder_gt
        border = args.scale
        window_size = 8

    # 003 real-world image sr
    elif args.task in ['real_sr']:
        save_dir = f'results/swinir_{args.task}_x{args.scale}'
        if args.large_model:
            save_dir += '_large'
        folder = args.folder_lq
        border = 0
        window_size = 8

    # 004 grayscale image denoising/ 005 color image denoising
    elif args.task in ['gray_dn', 'color_dn']:
        save_dir = f'results/swinir_{args.task}_noise{args.noise}'
        folder = args.folder_gt
        border = 0
        window_size = 8

    # 006 JPEG compression artifact reduction
    elif args.task in ['jpeg_car', 'color_jpeg_car']:
        save_dir = f'results/swinir_{args.task}_jpeg{args.jpeg}'
        folder = args.folder_gt
        border = 0
        window_size = 7

    return folder, save_dir, border, window_size

# %%
def get_image_pair(args, path):
    (imgname, imgext) = os.path.splitext(os.path.basename(path))

    # 001 classical image sr/ 002 lightweight image sr (load lq-gt image pairs)
    if args.task in ['classical_sr', 'lightweight_sr']:
        img_gt = cv2.imread(path, cv2.IMREAD_COLOR).astype(np.float32) / 255.
        img_lq = cv2.imread(f'{args.folder_lq}/{imgname}x{args.scale}{imgext}', cv2.IMREAD_COLOR).astype(
            np.float32) / 255.

    # 003 real-world image sr (load lq image only)
    elif args.task in ['real_sr']:
        img_gt = None
        img_lq = cv2.imread(path, cv2.IMREAD_COLOR).astype(np.float32) / 255.

    # 004 grayscale image denoising (load gt image and generate lq image on-the-fly)
    elif args.task in ['gray_dn']:
        img_gt = cv2.imread(path, cv2.IMREAD_GRAYSCALE).astype(np.float32) / 255.
        np.random.seed(seed=0)
        img_lq = img_gt + np.random.normal(0, args.noise / 255., img_gt.shape)
        img_gt = np.expand_dims(img_gt, axis=2)
        img_lq = np.expand_dims(img_lq, axis=2)

    # 005 color image denoising (load gt image and generate lq image on-the-fly)
    elif args.task in ['color_dn']:
        img_gt = cv2.imread(path, cv2.IMREAD_COLOR).astype(np.float32) / 255.
        np.random.seed(seed=0)
        img_lq = img_gt + np.random.normal(0, args.noise / 255., img_gt.shape)

    # 006 grayscale JPEG compression artifact reduction (load gt image and generate lq image on-the-fly)
    elif args.task in ['jpeg_car']:
        img_gt = cv2.imread(path, cv2.IMREAD_UNCHANGED)
        if img_gt.ndim != 2:
            img_gt = util.bgr2ycbcr(img_gt, y_only=True)
        result, encimg = cv2.imencode('.jpg', img_gt, [int(cv2.IMWRITE_JPEG_QUALITY), args.jpeg])
        img_lq = cv2.imdecode(encimg, 0)
        img_gt = np.expand_dims(img_gt, axis=2).astype(np.float32) / 255.
        img_lq = np.expand_dims(img_lq, axis=2).astype(np.float32) / 255.

    # 006 JPEG compression artifact reduction (load gt image and generate lq image on-the-fly)
    elif args.task in ['color_jpeg_car']:
        img_gt = cv2.imread(path)
        result, encimg = cv2.imencode('.jpg', img_gt, [int(cv2.IMWRITE_JPEG_QUALITY), args.jpeg])
        img_lq = cv2.imdecode(encimg, 1)
        img_gt = img_gt.astype(np.float32)/ 255.
        img_lq = img_lq.astype(np.float32)/ 255.

    return imgname, img_lq, img_gt

# %%
def test(img_lq, model, args, window_size):
    if args.tile is None:
        # test the image as a whole
        output = model(img_lq)
    else:
        # test the image tile by tile
        b, c, h, w = img_lq.size()
        tile = min(args.tile, h, w)
        assert tile % window_size == 0, "tile size should be a multiple of window_size"
        tile_overlap = args.tile_overlap
        sf = args.scale

        stride = tile - tile_overlap
        h_idx_list = list(range(0, h-tile, stride)) + [h-tile]
        w_idx_list = list(range(0, w-tile, stride)) + [w-tile]
        E = torch.zeros(b, c, h*sf, w*sf).type_as(img_lq)
        W = torch.zeros_like(E)

        for h_idx in h_idx_list:
            for w_idx in w_idx_list:
                in_patch = img_lq[..., h_idx:h_idx+tile, w_idx:w_idx+tile]
                out_patch = model(in_patch)
                out_patch_mask = torch.ones_like(out_patch)

                E[..., h_idx*sf:(h_idx+tile)*sf, w_idx*sf:(w_idx+tile)*sf].add_(out_patch)
                W[..., h_idx*sf:(h_idx+tile)*sf, w_idx*sf:(w_idx+tile)*sf].add_(out_patch_mask)
        output = E.div_(W)

    return output

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--task', type=str, default='real_sr', help='classical_sr, lightweight_sr, real_sr, '
                                                                    'gray_dn, color_dn, jpeg_car, color_jpeg_car')
parser.add_argument('--scale', type=int, default=4, help='scale factor: 1, 2, 3, 4, 8') # 1 for dn and jpeg car
parser.add_argument('--noise', type=int, default=15, help='noise level: 15, 25, 50')
parser.add_argument('--jpeg', type=int, default=40, help='scale factor: 10, 20, 30, 40')
parser.add_argument('--training_patch_size', type=int, default=128, help='patch size used in training SwinIR. '
                                    'Just used to differentiate two different settings in Table 2 of the paper. '
                                    'Images are NOT tested patch by patch.')
parser.add_argument('--large_model', action='store_true', help='use large model, only provided for real image sr')
parser.add_argument('--model_path', type=str,
                    default='model_zoo/swinir/003_realSR_BSRGAN_DFOWMFC_s64w8_SwinIR-L_x4_GAN.pth')
# --folder_lq 대신 입력 루트 폴더 (open/trains 같은)
parser.add_argument('--input_root_folder', type=str, required=True, help='Root folder containing class subfolders (e.g., open/trains)')
# 새로운 출력 루트 폴더 (upscaled/trains 같은)
parser.add_argument('--output_root_folder', type=str, required=True, help='Root folder to save upscaled images (e.g., upscaled/trains)')
    
parser.add_argument('--tile', type=int, default=None, help='Tile size, None for no tile during testing (testing as a whole)')
parser.add_argument('--tile_overlap', type=int, default=32, help='Overlapping of different tiles')
parser.add_argument('--target_resolution', type=int, default=1024, help='Target resolution for upscaled images (e.g., 1024)')
 # --- 여기서부터 핵심 ---
    # parse_args()에 인자 리스트를 직접 전달합니다.
    # 이렇게 하면 sys.argv를 건드리지 않고도 argparse를 사용할 수 있습니다.
args = parser.parse_args([
    # '--task', 'real_sr',
    # '--scale', '4',
    # '--large_model', # action='store_true'는 값 없이 플래그만 지정
    # '--model_path', 'model_zoo/swinir/003_realSR_BSRGAN_DFOWMFC_s64w8_SwinIR-L_x4_GAN.pth',
    '--input_root_folder', 'C:/Naver_Boostcourse/HAI!/open/train', # 실제 경로로 변경하세요!
    '--output_root_folder', 'C:/Naver_Boostcourse/HAI!/upscaled/train', # 실제 경로로 변경하세요!
    '--target_resolution', '1024',
    '--tile', '512', # 예시: 타일링을 사용하려면 이 주석을 해제하고 값을 설정
    '--tile_overlap', '32' # 타일링 사용 시 오버랩
])

#args = parser.parse_args()

# %%
# --- 동적 모델 선택을 위한 모델 경로 및 설정 매핑 ---
# 각 스케일에 맞는 모델 경로와 기타 파라미터 (예: task, training_patch_size, large_model 여부)를 설정
# 여기서는 'classical_sr' 태스크에 초점을 맞춥니다.
# 필요하다면 다른 task에 대한 모델도 여기에 추가할 수 있습니다.
scale_configs = {
            # 실제 이미지 SR 모델 추가 (x2)
        2: { 
            'model_path': 'model_zoo/swinir/003_realSR_BSRGAN_DFO_s64w8_SwinIR-M_x2_GAN-with-dict-keys-params-and-params_ema.pth',
            'task': 'real_sr',
            'training_patch_size': 64,
            'large_model': False, # SwinIR-M이므로 large_model은 False
            'param_key': 'params_ema' 
        },
        # 실제 이미지 SR 모델 추가 (x4)
        4: { 
            'model_path': 'model_zoo/swinir/003_realSR_BSRGAN_DFOWMFC_s64w8_SwinIR-L_x4_GAN-with-dict-keys-params-and-params_ema.pth', 
            'task': 'real_sr',
            'training_patch_size': 64,
            'large_model': True, # SwinIR-L이므로 large_model은 True
            'param_key': 'params_ema' 
        },
    # 2: {
    #     'model_path': 'model_zoo/swinir/001_classicalSR_DF2K_s64w8_SwinIR-M_x2.pth',
    #     'task': 'classical_sr',
    #     'training_patch_size': 64,
    #     'large_model': False
    # },
    # 3: {
    #     'model_path': 'model_zoo/swinir/001_classicalSR_DF2K_s64w8_SwinIR-M_x3.pth',
    #     'task': 'classical_sr',
    #     'training_patch_size': 64,
    #     'large_model': False
    # },
    # 4: {
    #     'model_path': 'model_zoo/swinir/001_classicalSR_DF2K_s64w8_SwinIR-M_x4.pth',
    #     'task': 'classical_sr',
    #     'training_patch_size': 64,
    #     'large_model': False
    # },
    # 8: {
    #     'model_path': 'model_zoo/swinir/001_classicalSR_DF2K_s64w8_SwinIR-M_x8.pth',
    #     'task': 'classical_sr',
    #     'training_patch_size': 64,
    #     'large_model': False
    # },
    # 다른 스케일이나 태스크가 있다면 여기에 추가
    # 예: 4 (real_sr): {'model_path': 'model_zoo/swinir/003_realSR_BSRGAN_DFOWMFC_s64w8_SwinIR-L_x4_GAN.pth',
    #                   'task': 'real_sr', 'training_patch_size': 64, 'large_model': True}
}

# 사용 가능한 스케일 팩터를 내림차순으로 정렬하여, 가장 작은 스케일 팩터부터 시도하도록 합니다.
# 목표 해상도를 넘어서는 최소 배율을 찾기 위함입니다.
supported_scales = sorted(scale_configs.keys())

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# --- 여기서 출력 루트 폴더를 초기화합니다 ---
# if not initialize_output_root(args.output_root_folder):
#     print("Initialization of output directory failed. Exiting.")
#     pass # 초기화 실패 시 프로그램 종료

window_size = 8 # classical_sr에 맞는 기본 window_size

# 모델은 이미지마다 로드하는 대신, 필요한 스케일에 따라 한 번씩만 로드하도록 최적화
loaded_models = {}

# %%
print(f"Target Resolution: {args.target_resolution}")

# 입력 이미지 탐색 (glob.glob으로 재귀적으로 탐색)
# JPEG, PNG 등의 이미지 확장자를 모두 포함
image_paths = sorted(glob.glob(os.path.join(args.input_root_folder, '**', '*.[jJpP][pPeE][gGgG]*'), recursive=True))
image_paths.extend(sorted(glob.glob(os.path.join(args.input_root_folder, '**', '*.[pP][nN][gG]*'), recursive=True)))
image_paths = sorted(list(set(image_paths))) # 중복 제거 및 정렬
if not image_paths:
    print(f"No images found in {args.input_root_folder}. Please check the path and image extensions.")
    pass

print(f"Found {len(image_paths)} images to process.")

for idx, path in enumerate(image_paths):

    if idx < 15692:
        continue

    # 경로를 운영체제에 맞는 정규화된 형태로 변환
    normalized_path = os.path.normpath(path)

    # 출력 경로 생성
    relative_path = os.path.relpath(normalized_path, args.input_root_folder)
    output_sub_folder = os.path.dirname(os.path.join(args.output_root_folder, relative_path))
    os.makedirs(output_sub_folder, exist_ok=True) 
    
    imgname, imgext = os.path.splitext(os.path.basename(normalized_path))
    output_path = os.path.join(output_sub_folder, f'{imgname}.png') # PNG로 저장 (투명 배경 가능성 고려)

    print(f"\nProcessing ({idx+1}/{len(image_paths)}): {path} -> {output_path}")

    # --- 이미지 로드 (한글 경로 문제 해결) ---
    try:
        with open(path, 'rb') as f:
            bytes_data = f.read() 
        np_array = np.frombuffer(bytes_data, np.uint8)
        # img_lq는 HWC-BGR, uint8, 0-255 범위
        img_lq_bgr_uint8 = cv2.imdecode(np_array, cv2.IMREAD_COLOR) 
        if img_lq_bgr_uint8 is None:
            raise Exception("Failed to decode image.")
    except Exception as e:
        print(f"Warning: Could not read image {path} due to error: {e}. Skipping.")
        continue # 이미지 읽기 실패 시 다음 이미지로 넘어감

    # --- 원본 이미지 해상도 확인 및 동적 스케일 팩터 선택 로직 ---
    h_orig, w_orig = img_lq_bgr_uint8.shape[:2]
    
    selected_scale = 1 # 기본값은 스케일 업 없음 (만약 모든 배율로도 목표 해상도에 미달하면)
    
    # 목표 해상도(args.target_resolution)를 초과하는 최소 스케일을 찾기
    # 즉, 목표 해상도에 가장 가까우면서 최소한의 업스케일링을 제공하는 스케일 선택
    for s in supported_scales: # 2, 3, 4, 8 순서로 정렬됨   
        if h_orig * s >= args.target_resolution or w_orig * s >= args.target_resolution:
            selected_scale = s
            break # 1024를 넘어서는 첫 번째 스케일을 찾으면 루프 종료
    
    # 만약 어떤 스케일로도 target_resolution에 도달하지 못하면 가장 큰 스케일을 사용합니다.
    if selected_scale == 1:
        # 원본 이미지의 어느 한 변이 이미 목표 해상도를 넘거나 같을 경우
        if h_orig >= args.target_resolution or w_orig >= args.target_resolution:
            print(f"  Image {imgname} already meets or exceeds target resolution ({h_orig}x{w_orig}). Skipping upscaling.")
            # 모델 추론을 건너뛰고, 원본 이미지를 바로 PIL로 변환하여 최종 리사이즈 단계로 넘김
            # cv2.imdecode는 BGR이므로, PIL을 위해 RGB로 변환해야 함
            img_for_final_resize = cv2.cvtColor(img_lq_bgr_uint8, cv2.COLOR_BGR2RGB)
            final_img = Image.fromarray(img_for_final_resize)
            
        else: # 어떤 스케일로도 target_resolution에 도달하지 못하면 가장 큰 스케일 강제 적용
            selected_scale = max(supported_scales) 
            print(f"  No scale factor reaches target resolution {args.target_resolution}. Using largest available scale: x{selected_scale}")
            # 이제 selected_scale이 1이 아니므로 아래 모델 추론 블록으로 진입
    
    if selected_scale != 1: # 스케일업이 필요한 경우에만 모델 추론
        print(f"  Original resolution: {h_orig}x{w_orig}. Selected scale: x{selected_scale}")

        current_config = scale_configs[selected_scale]
        args.scale = selected_scale # args.scale 업데이트
        args.model_path = current_config['model_path']
        args.task = current_config['task']
        args.training_patch_size = current_config['training_patch_size']
        args.large_model = current_config['large_model']
        args.param_key = current_config['param_key']
        
        # 이미 로드된 모델이 있는지 확인하고 재사용
        if selected_scale not in loaded_models:
            print(f'  Loading model for scale x{selected_scale} from {args.model_path}')
            if not os.path.exists(args.model_path):
                os.makedirs(os.path.dirname(args.model_path), exist_ok=True)
                url = 'https://github.com/JingyunLiang/SwinIR/releases/download/v0.0/{}'.format(os.path.basename(args.model_path))
                print(f'  Downloading model {args.model_path} from {url}')
                try:
                    r = requests.get(url, allow_redirects=True, timeout=30)
                    r.raise_for_status() # HTTP 오류가 발생하면 예외 발생
                    with open(args.model_path, 'wb') as f:
                        f.write(r.content)
                    print(f'  Model downloaded successfully to {args.model_path}')
                except requests.exceptions.RequestException as e:
                    print(f"Error downloading model: {e}")
                    print("Please check your internet connection or the model URL. Skipping this image.")
                    continue # 모델 다운로드 실패 시 다음 이미지로 넘어감
            
            model = define_model(args)
            model.eval()
            model = model.to(device)
            loaded_models[selected_scale] = model # 로드된 모델 저장
        else:
            print(f'  Reusing already loaded model for scale x{selected_scale}')
            model = loaded_models[selected_scale] # 로드된 모델 재사용

        # --- 이미지 전처리 (모델 입력용) ---
        # 원본 BGR uint8 이미지를 RGB float32 0-1 범위로 변환 후, Torch 텐서로 변환
        img_lq_rgb_float = cv2.cvtColor(img_lq_bgr_uint8, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.
        img_lq_chw_rgb = np.transpose(img_lq_rgb_float, (2, 0, 1)) # HWC to CHW
        img_lq_tensor = torch.from_numpy(img_lq_chw_rgb).float().unsqueeze(0).to(device) # CHW to NCHW

        # --- 모델 추론 ---
        with torch.no_grad():
            current_window_size = 8 # classical_sr 모델의 window_size
            if args.task in ['jpeg_car', 'color_jpeg_car']: 
                current_window_size = 7

            _, _, h_old, w_old = img_lq_tensor.size()
            h_pad = (h_old // current_window_size + 1) * current_window_size - h_old
            w_pad = (w_old // current_window_size + 1) * current_window_size - w_old
            
            # 이미지 패딩
            img_lq_padded = torch.cat([img_lq_tensor, torch.flip(img_lq_tensor, [2])], 2)[:, :, :h_old + h_pad, :]
            img_lq_padded = torch.cat([img_lq_padded, torch.flip(img_lq_padded, [3])], 3)[:, :, :, :w_old + w_pad]
            
            # 모델 추론
            output_tensor = test(img_lq_padded, model, args, current_window_size)
            # 패딩 제거
            output_tensor = output_tensor[..., :h_old * args.scale, :w_old * args.scale]

        # --- 모델 출력 후처리 ---
        # Torch Tensor -> NumPy 배열 (RGB, CHW -> HWC)
        output_np = output_tensor.data.squeeze().float().cpu().numpy() 
        
        print(f"  Model output (before clamping): min={output_np.min():.4f}, max={output_np.max():.4f}, mean={output_np.mean():.4f}")

        output_np = np.clip(output_np, 0, 1) # 0-1 범위로 클램핑
        
        # CHW-RGB -> HWC-RGB (PIL.Image.fromarray가 HWC를 기대)
        if output_np.ndim == 3:
            output_np = np.transpose(output_np, (1, 2, 0)) 
        
        # 0-1 float32 -> 0-255 uint8 변환
        output_np_uint8 = (output_np * 255.0).round().astype(np.uint8) 

        # PIL Image 객체로 변환 (RGB 순서)
        final_img = Image.fromarray(output_np_uint8)

    # --- 최종 해상도 조절 (Upscaling 후 또는 Upscaling 건너뛴 후) ---
    width, height = final_img.size
    target_resolution = args.target_resolution # 1024

    # 가로 또는 세로 중 더 긴 변을 target_resolution에 맞추면서 비율 유지
    if width > height:
        new_width = target_resolution
        new_height = int(height * (target_resolution / width))
    else:
        new_height = target_resolution
        new_width = int(width * (target_resolution / height))
    
    # 새로운 크기로 리사이즈 (LANCZOS는 고품질 리사이즈 알고리즘)
    if final_img.size != (new_width, new_height): # 이미 같은 크기면 리사이즈 불필요
        final_img = final_img.resize((new_width, new_height), Image.LANCZOS)
        print(f"  Resized to final target resolution: {new_width}x{new_height}")
    else:
        print(f"  Final image resolution is already {new_width}x{new_height}. No further resizing needed.")


    # --- 이미지 저장 (한글 경로 문제 및 채널 순서 일관성 유지) ---
    try:
        # PIL Image를 NumPy 배열로 변환 (PIL은 기본적으로 RGB HWC)
        img_to_save_np_rgb = np.array(final_img)    
        
        # cv2.imencode는 BGR 순서를 기대하므로, RGB -> BGR로 변환
        img_to_save_np_bgr = cv2.cvtColor(img_to_save_np_rgb, cv2.COLOR_RGB2BGR)

        # PNG 형식으로 인코딩
        is_success, buffer = cv2.imencode(".png", img_to_save_np_bgr) 
        if is_success: 
            # 바이트 데이터를 파일에 쓰기
            with open(output_path, 'wb') as f:
                f.write(buffer.tobytes()) 
            print(f"  Image saved to: {output_path}")
        else:
            print(f"Error: Could not encode image for saving to {output_path}. Check file format support.")
    except Exception as e:
        print(f"Error: Could not save image to {output_path} due to error: {e}.")

print("\n--- All images upscaled and saved. ---")
# Out:
# Target Resolution: 1024
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 5
#       1 print(f"Target Resolution: {args.target_resolution}")
#       3 # 입력 이미지 탐색 (glob.glob으로 재귀적으로 탐색)
#       4 # JPEG, PNG 등의 이미지 확장자를 모두 포함
# ----> 5 image_paths = sorted(glob.glob(os.path.join(args.input_root_folder, '**', '*.[jJpP][pPeE][gGgG]*'), recursive=True))
#       6 image_paths.extend(sorted(glob.glob(os.path.join(args.input_root_folder, '**', '*.[pP][nN][gG]*'), recursive=True)))
#       7 image_paths = sorted(list(set(image_paths))) # 중복 제거 및 정렬
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\glob.py:28, in glob(pathname, root_dir, dir_fd, recursive, include_hidden)
#      13 def glob(pathname, *, root_dir=None, dir_fd=None, recursive=False,
#      14         include_hidden=False):
#      15     """Return a list of paths matching a pathname pattern.
#      16
#      17     The pattern may contain simple shell-style wildcards a la
#    (...)
#      26     zero or more directories and subdirectories.
#      27     """
# ---> 28     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive,
#      29                       include_hidden=include_hidden))
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\glob.py:97, in _iglob(pathname, root_dir, dir_fd, recursive, dironly, include_hidden)
#      95     glob_in_dir = _glob0
#      96 for dirname in dirs:
# ---> 97     for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly,
#      98                            include_hidden=include_hidden):
#      99         yield os.path.join(dirname, name)
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\glob.py:106, in _glob1(dirname, pattern, dir_fd, dironly, include_hidden)
#     105 def _glob1(dirname, pattern, dir_fd, dironly, include_hidden=False):
# --> 106     names = _listdir(dirname, dir_fd, dironly)
#     107     if include_hidden or not _ishidden(pattern):
#     108         names = (x for x in names if include_hidden or not _ishidden(x))
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\glob.py:178, in _listdir(dirname, dir_fd, dironly)
#     176 def _listdir(dirname, dir_fd, dironly):
#     177     with contextlib.closing(_iterdir(dirname, dir_fd, dironly)) as it:
# --> 178         return list(it)
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\glob.py:167, in _iterdir(dirname, dir_fd, dironly)
#     165             yield fsencode(entry.name)
#     166         else:
# --> 167             yield entry.name
#     168 except OSError:
#     169     pass
#
# KeyboardInterrupt:

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# # set up model
# if os.path.exists(args.model_path):
#     print(f'loading model from {args.model_path}')
# else:
#     os.makedirs(os.path.dirname(args.model_path), exist_ok=True)
#     url = 'https://github.com/JingyunLiang/SwinIR/releases/download/v0.0/{}'.format(os.path.basename(args.model_path))
#     r = requests.get(url, allow_redirects=True)
#     print(f'downloading model {args.model_path}')
#     open(args.model_path, 'wb').write(r.content)

# model = define_model(args)
# model.eval()
# model = model.to(device)

# # 입력 이미지 탐색 (glob.glob으로 재귀적으로 탐색)
# # JPEG, PNG 등의 이미지 확장자를 모두 포함
# image_paths = sorted(glob.glob(os.path.join(args.input_root_folder, '**', '*.[jJpP][pPeE][gGgG]*'), recursive=True))
# image_paths.extend(sorted(glob.glob(os.path.join(args.input_root_folder, '**', '*.[pP][nN][gG]*'), recursive=True)))
# image_paths = sorted(list(set(image_paths))) # 중복 제거 및 정렬
# if not image_paths:
#     print(f"No images found in {args.input_root_folder}. Please check the path and image extensions.")
#     pass

# print(f"Found {len(image_paths)} images to process.")

# window_size = 8 # SwinIR 모델의 window_size (대부분 8, real_sr은 7일수도 있음)
# if args.task in ['jpeg_car', 'color_jpeg_car']:
#     window_size = 7 # JPEG artifact reduction task

#  # --- 여기서 출력 루트 폴더를 초기화합니다 ---
# if not initialize_output_root(args.output_root_folder):
#     print("Initialization of output directory failed. Exiting.")
#     pass # 초기화 실패 시 프로그램 종료

# for idx, path in enumerate(image_paths):
#     # 경로를 운영체제에 맞는 정규화된 형태로 변환
#     normalized_path = os.path.normpath(path)

#     # 원본 파일 경로에서 클래스명과 이미지 파일명 추출
#     relative_path = os.path.relpath(normalized_path, args.input_root_folder) # open/trains/ 뒤의 경로
#     # 예: 2시리즈_그란쿠페_F44_2020_2024\2시리즈_그란쿠페_F44_2020_2024_0000.jpg
    
#     # 출력 경로 생성
#     output_sub_folder = os.path.dirname(os.path.join(args.output_root_folder, relative_path))
#     os.makedirs(output_sub_folder, exist_ok=True)
    
#     imgname, imgext = os.path.splitext(os.path.basename(normalized_path))
#     output_path = os.path.join(output_sub_folder, f'{imgname}.png') # PNG로 저장 (투명 배경 가능성 고려)

#     print(f"Processing ({idx+1}/{len(image_paths)}): {path} -> {output_path}")

#     # 이미지 로드 및 전처리
#     # cv2.imread는 BGR, SwinIR은 RGB를 선호하므로 변환 필요
#     # SwinIR 모델은 0~1 범위의 float32를 선호
#     try:
#         # 파일을 바이트 스트림으로 읽음 (한글 경로 문제 회피)
#         with open(path, 'rb') as f:
#             bytes_data = f.read()
#         # 바이트 데이터를 numpy 배열로 변환
#         np_array = np.frombuffer(bytes_data, np.uint8)
#         # numpy 배열을 OpenCV 이미지로 디코딩   
#         img_lq = cv2.imdecode(np_array, cv2.IMREAD_COLOR)

#     except Exception as e:
#         print(f"Warning: Could not read image {normalized_path} due to error: {e}. Skipping.")
#         img_lq = None # 읽기 실패 시 img_lq를 None으로 설정

#     if img_lq is None:
#         print(f"Warning: Failed to load image {normalized_path}. It might be corrupted or not exist. Skipping.")
#         continue # 이미지를 읽지 못했으므로 다음 이미지로 넘어감
#     # --- 이 부분이 중요합니다: 0-255 uint8 -> 0-1 float32 정규화 ---
#     img_lq = img_lq.astype(np.float32) / 255.

#     # HWC-BGR to CHW-RGB (SwinIR 모델 입력 형식)
#     img_lq = np.transpose(img_lq[:, :, [2, 1, 0]], (2, 0, 1))
#     img_lq = torch.from_numpy(img_lq).float().unsqueeze(0).to(device)

#     # inference
#     with torch.no_grad():
#         # 이미지 패딩 (window_size의 배수로)
#         _, _, h_old, w_old = img_lq.size()
#         h_pad = (h_old // window_size + 1) * window_size - h_old
#         w_pad = (w_old // window_size + 1) * window_size - w_old
#         img_lq = torch.cat([img_lq, torch.flip(img_lq, [2])], 2)[:, :, :h_old + h_pad, :]
#         img_lq = torch.cat([img_lq, torch.flip(img_lq, [3])], 3)[:, :, :, :w_old + w_pad]
        
#         output = test(img_lq, model, args, window_size)
#         # 패딩 제거 및 원본 스케일로 조정
#         output = output[..., :h_old * args.scale, :w_old * args.scale]

#     # --- 결과 이미지 후처리 및 저장 ---
#     output = output.data.squeeze().float().cpu().numpy() # clamp_ 제거 후 numpy로 변환

#     # 값 범위를 0-1로 클램핑 (0보다 작거나 1보다 큰 값 보정)
#     output = np.clip(output, 0, 1) # np.clip 사용
#     if output.ndim == 3:
#         output = np.transpose(output[[2, 1, 0], :, :], (1, 2, 0)) # CHW-RGB to HWC-BGR for cv2
#     output = (output * 255.0).round().astype(np.uint8) # float32 to uint8   
# # 최종 해상도 1024x1024로 강제 리사이즈 (가로세로 비율 유지)
#     final_img = Image.fromarray(output)

#     # 이미지의 현재 가로, 세로 길이
#     width, height = final_img.size
#     target_resolution = args.target_resolution # 1024

#     # 가로 또는 세로 중 더 긴 길이를 1024로 맞추면서 비율 유지
#     if width > height:
#         # 가로가 더 길면, 가로를 target_resolution으로 맞추고 세로를 비율에 따라 조정
#         new_width = target_resolution
#         new_height = int(height * (target_resolution / width))
#     else:
#         # 세로가 더 길거나 같으면, 세로를 target_resolution으로 맞추고 가로를 비율에 따라 조정
#         new_height = target_resolution
#         new_width = int(width * (target_resolution / height))
    
#     # 새로운 크기로 리사이즈
#     final_img = final_img.resize((new_width, new_height), Image.LANCZOS) # 고품질 리사이즈
        
#     # --- 이미지 저장 부분 (한글 경로 문제 해결) ---
#     try:
#         # PIL Image를 numpy 배열로 변환
#         img_to_save_np = np.array(final_img)    
#         # 파일 확장자에 따라 인코딩 형식 지정 (여기서는 PNG)
#         # PNG 형식은 품질 손실이 없으므로 업스케일된 결과 저장에 적합합니다.
#         is_success, buffer = cv2.imencode(".png", img_to_save_np)
#         if is_success:
#             # 바이트 데이터를 파일에 쓰기
#             with open(output_path, 'wb') as f:
#                 f.write(buffer.tobytes())
#             print(f"Image saved to: {output_path}")
#         else:
#             print(f"Error: Could not encode image for saving to {output_path}.")
#     except Exception as e:
#         print(f"Error: Could not save image to {output_path} due to error: {e}.")

# print("\n--- All images upscaled and saved. ---")
# Out:
# loading model from model_zoo/swinir/003_realSR_BSRGAN_DFOWMFC_s64w8_SwinIR-L_x4_GAN.pth
# C:\Users\bug95\AppData\Local\Temp\ipykernel_34920\1483256617.py:62: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_model = torch.load(args.model_path)
# Found 33137 images to process.
# Output root directory 'C:/Naver_Boostcourse/HAI!/upscaled/train' already exists. Deleting its content...
# Directory 'C:/Naver_Boostcourse/HAI!/upscaled/train' deleted successfully.
# Directory 'C:/Naver_Boostcourse/HAI!/upscaled/train' created successfully.
# Processing (1/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0000.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0000.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0000.png
# Processing (2/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0001.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0001.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0001.png
# Processing (3/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0002.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0002.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0002.png
# Processing (4/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0003.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0003.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0003.png
# Processing (5/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0004.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0004.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0004.png
# Processing (6/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0005.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0005.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0005.png
# Processing (7/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0006.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0006.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0006.png
# Processing (8/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0007.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0007.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0007.png
# Processing (9/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0008.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0008.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0008.png
# Processing (10/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0009.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0009.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0009.png
# Processing (11/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0010.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0010.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0010.png
# Processing (12/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0011.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0011.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0011.png
# Processing (13/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0012.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0012.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0012.png
# Processing (14/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0013.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0013.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0013.png
# Processing (15/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0014.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0014.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0014.png
# Processing (16/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0015.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0015.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0015.png
# Processing (17/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0016.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0016.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0016.png
# Processing (18/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0017.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0017.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0017.png
# Processing (19/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0018.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0018.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0018.png
# Processing (20/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0019.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0019.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0019.png
# Processing (21/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0020.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0020.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0020.png
# Processing (22/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0021.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0021.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0021.png
# Processing (23/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0022.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0022.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0022.png
# Processing (24/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0023.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0023.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0023.png
# Processing (25/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0024.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0024.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0024.png
# Processing (26/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0025.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0025.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0025.png
# Processing (27/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0026.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0026.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0026.png
# Processing (28/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0027.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0027.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0027.png
# Processing (29/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0028.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0028.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0028.png
# Processing (30/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0029.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0029.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0029.png
# Processing (31/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0030.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0030.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0030.png
# Processing (32/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0031.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0031.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0031.png
# Processing (33/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0032.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0032.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0032.png
# Processing (34/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0033.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0033.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0033.png
# Processing (35/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0034.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0034.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0034.png
# Processing (36/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0035.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0035.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0035.png
# Processing (37/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0036.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0036.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0036.png
# Processing (38/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0037.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0037.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0037.png
# Processing (39/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0038.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0038.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0038.png
# Processing (40/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0039.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0039.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0039.png
# Processing (41/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0040.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0040.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0040.png
# Processing (42/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0041.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0041.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0041.png
# Processing (43/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0042.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0042.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0042.png
# Processing (44/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0043.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0043.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0043.png
# Processing (45/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0044.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0044.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0044.png
# Processing (46/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0045.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0045.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0045.png
# Processing (47/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0046.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0046.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0046.png
# Processing (48/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0047.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0047.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0047.png
# Processing (49/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0048.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0048.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0048.png
# Processing (50/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0049.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0049.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0049.png
# Processing (51/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0050.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0050.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0050.png
# Processing (52/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0051.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0051.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0051.png
# Processing (53/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0052.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0052.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0052.png
# Processing (54/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0053.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0053.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0053.png
# Processing (55/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0054.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0054.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0054.png
# Processing (56/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0055.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0055.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0055.png
# Processing (57/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0056.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0056.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0056.png
# Processing (58/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0057.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0057.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0057.png
# Processing (59/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0058.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0058.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0058.png
# Processing (60/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0059.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0059.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0059.png
# Processing (61/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0060.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0060.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0060.png
# Processing (62/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0061.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0061.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0061.png
# Processing (63/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0062.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0062.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0062.png
# Processing (64/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0063.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0063.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0063.png
# Processing (65/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0064.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0064.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0064.png
# Processing (66/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0065.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0065.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0065.png
# Processing (67/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0066.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0066.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0066.png
# Processing (68/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0067.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0067.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0067.png
# Processing (69/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0068.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0068.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0068.png
# Processing (70/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0069.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0069.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0069.png
# Processing (71/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0070.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0070.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0070.png
# Processing (72/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0071.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0071.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0071.png
# Processing (73/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0072.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0072.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0072.png
# Processing (74/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0073.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0073.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0073.png
# Processing (75/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0074.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0074.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0074.png
# Processing (76/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0075.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0075.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0075.png
# Processing (77/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0076.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0076.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0076.png
# Processing (78/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0077.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0077.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0077.png
# Processing (79/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0078.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0078.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0078.png
# Processing (80/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0079.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0079.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0079.png
# Processing (81/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0080.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0080.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0080.png
# Processing (82/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0081.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0081.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0081.png
# Processing (83/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0082.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0082.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0082.png
# Processing (84/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0083.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0083.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0083.png
# Processing (85/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0084.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0084.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0084.png
# Processing (86/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0085.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0085.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2013_2015\1시리즈_F20_2013_2015_0085.png
# Processing (87/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0000.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0000.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0000.png
# Processing (88/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0001.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0001.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0001.png
# Processing (89/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0002.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0002.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0002.png
# Processing (90/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0003.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0003.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0003.png
# Processing (91/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0004.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0004.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0004.png
# Processing (92/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0005.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0005.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0005.png
# Processing (93/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0006.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0006.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0006.png
# Processing (94/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0007.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0007.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0007.png
# Processing (95/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0008.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0008.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0008.png
# Processing (96/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0009.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0009.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0009.png
# Processing (97/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0010.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0010.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0010.png
# Processing (98/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0011.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0011.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0011.png
# Processing (99/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0012.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0012.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0012.png
# Processing (100/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0013.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0013.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0013.png
# Processing (101/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0014.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0014.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0014.png
# Processing (102/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0015.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0015.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0015.png
# Processing (103/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0016.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0016.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0016.png
# Processing (104/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0017.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0017.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0017.png
# Processing (105/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0018.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0018.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0018.png
# Processing (106/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0019.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0019.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0019.png
# Processing (107/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0020.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0020.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0020.png
# Processing (108/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0021.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0021.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0021.png
# Processing (109/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0022.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0022.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0022.png
# Processing (110/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0023.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0023.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0023.png
# Processing (111/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0024.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0024.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0024.png
# Processing (112/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0025.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0025.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0025.png
# Processing (113/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0026.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0026.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0026.png
# Processing (114/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0027.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0027.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0027.png
# Processing (115/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0028.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0028.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0028.png
# Processing (116/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0029.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0029.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0029.png
# Processing (117/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0030.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0030.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0030.png
# Processing (118/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0031.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0031.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0031.png
# Processing (119/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0032.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0032.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0032.png
# Processing (120/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0033.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0033.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0033.png
# Processing (121/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0034.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0034.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0034.png
# Processing (122/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0035.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0035.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0035.png
# Processing (123/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0036.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0036.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0036.png
# Processing (124/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0037.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0037.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0037.png
# Processing (125/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0038.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0038.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0038.png
# Processing (126/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0039.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0039.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0039.png
# Processing (127/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0040.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0040.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0040.png
# Processing (128/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0041.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0041.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0041.png
# Processing (129/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0042.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0042.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0042.png
# Processing (130/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0043.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0043.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0043.png
# Processing (131/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0044.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0044.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0044.png
# Processing (132/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0045.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0045.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0045.png
# Processing (133/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0046.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0046.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0046.png
# Processing (134/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0047.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0047.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0047.png
# Processing (135/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0048.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0048.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0048.png
# Processing (136/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0049.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0049.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0049.png
# Processing (137/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0050.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0050.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0050.png
# Processing (138/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0051.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0051.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0051.png
# Processing (139/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0052.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0052.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0052.png
# Processing (140/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0053.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0053.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0053.png
# Processing (141/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0054.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0054.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0054.png
# Processing (142/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0055.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0055.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0055.png
# Processing (143/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0056.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0056.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0056.png
# Processing (144/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0057.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0057.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0057.png
# Processing (145/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0058.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0058.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0058.png
# Processing (146/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0059.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0059.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0059.png
# Processing (147/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0060.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0060.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0060.png
# Processing (148/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0061.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0061.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0061.png
# Processing (149/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0062.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0062.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0062.png
# Processing (150/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0063.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0063.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0063.png
# Processing (151/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0064.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0064.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0064.png
# Processing (152/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0065.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0065.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0065.png
# Processing (153/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0066.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0066.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0066.png
# Processing (154/33137): C:/Naver_Boostcourse/HAI!/open/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0067.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0067.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\1시리즈_F20_2016_2019\1시리즈_F20_2016_2019_0067.png
# ...
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0020.png
# Processing (270/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0021.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0021.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0021.png
# Processing (271/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0022.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0022.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0022.png
# Processing (272/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0023.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0023.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0023.png
# Processing (273/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0024.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0024.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0024.png
# Processing (274/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0025.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0025.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0025.png
# Processing (275/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0026.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0026.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0026.png
# Processing (276/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0027.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0027.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0027.png
# Processing (277/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0028.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0028.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0028.png
# Processing (278/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0029.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0029.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0029.png
# Processing (279/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0030.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0030.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0030.png
# Processing (280/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0031.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0031.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0031.png
# Processing (281/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0032.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0032.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0032.png
# Processing (282/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0033.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0033.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0033.png
# Processing (283/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0034.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0034.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0034.png
# Processing (284/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0035.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0035.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0035.png
# Processing (285/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0036.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0036.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0036.png
# Processing (286/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0037.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0037.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0037.png
# Processing (287/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0038.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0038.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0038.png
# Processing (288/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0039.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0039.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0039.png
# Processing (289/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0040.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0040.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0040.png
# Processing (290/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0041.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0041.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0041.png
# Processing (291/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0042.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0042.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0042.png
# Processing (292/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0043.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0043.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0043.png
# Processing (293/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0044.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0044.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0044.png
# Processing (294/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0045.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0045.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0045.png
# Processing (295/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0046.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0046.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0046.png
# Processing (296/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0047.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0047.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0047.png
# Processing (297/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0048.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0048.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0048.png
# Processing (298/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0049.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0049.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0049.png
# Processing (299/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0050.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0050.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0050.png
# Processing (300/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0051.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0051.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0051.png
# Processing (301/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0052.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0052.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0052.png
# Processing (302/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0053.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0053.png
# Image saved to: C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0053.png
# Processing (303/33137): C:/Naver_Boostcourse/HAI!/open/train\2008_2015_2017\2008_2015_2017_0054.jpg -> C:/Naver_Boostcourse/HAI!/upscaled/train\2008_2015_2017\2008_2015_2017_0054.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 88
#      85 img_lq = torch.cat([img_lq, torch.flip(img_lq, [2])], 2)[:, :, :h_old + h_pad, :]
#      86 img_lq = torch.cat([img_lq, torch.flip(img_lq, [3])], 3)[:, :, :, :w_old + w_pad]
# ---> 88 output = test(img_lq, model, args, window_size)
#      89 # 패딩 제거 및 원본 스케일로 조정
#      90 output = output[..., :h_old * args.scale, :w_old * args.scale]
#
# Cell In[16], line 22, in test(img_lq, model, args, window_size)
#      20 for w_idx in w_idx_list:
#      21     in_patch = img_lq[..., h_idx:h_idx+tile, w_idx:w_idx+tile]
# ---> 22     out_patch = model(in_patch)
#      23     out_patch_mask = torch.ones_like(out_patch)
#      25     E[..., h_idx*sf:(h_idx+tile)*sf, w_idx*sf:(w_idx+tile)*sf].add_(out_patch)
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Naver_Boostcourse\HAI!\SwinIR\models\network_swinir.py:826, in SwinIR.forward(self, x)
#     823 elif self.upsampler == 'nearest+conv':
#     824     # for real-world SR
#     825     x = self.conv_first(x)
# --> 826     x = self.conv_after_body(self.forward_features(x)) + x
#     827     x = self.conv_before_upsample(x)
#     828     x = self.lrelu(self.conv_up1(torch.nn.functional.interpolate(x, scale_factor=2, mode='nearest')))
#
# File c:\Naver_Boostcourse\HAI!\SwinIR\models\network_swinir.py:798, in SwinIR.forward_features(self, x)
#     795 x = self.pos_drop(x)
#     797 for layer in self.layers:
# --> 798     x = layer(x, x_size)
#     800 x = self.norm(x)  # B L C
#     801 x = self.patch_unembed(x, x_size)
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Naver_Boostcourse\HAI!\SwinIR\models\network_swinir.py:482, in RSTB.forward(self, x, x_size)
#     481 def forward(self, x, x_size):
# --> 482     return self.patch_embed(self.conv(self.patch_unembed(self.residual_group(x, x_size), x_size))) + x
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Naver_Boostcourse\HAI!\SwinIR\models\network_swinir.py:402, in BasicLayer.forward(self, x, x_size)
#     400         x = checkpoint.checkpoint(blk, x, x_size)
#     401     else:
# --> 402         x = blk(x, x_size)
#     403 if self.downsample is not None:
#     404     x = self.downsample(x)
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bug95\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Naver_Boostcourse\HAI!\SwinIR\models\network_swinir.py:262, in SwinTransformerBlock.forward(self, x, x_size)
#     260     attn_windows = self.attn(x_windows, mask=self.attn_mask)  # nW*B, window_size*window_size, C
#     261 else:
# --> 262     attn_windows = self.attn(x_windows, mask=self.calculate_mask(x_size).to(x.device))
#     264 # merge windows
#     265 attn_windows = attn_windows.view(-1, self.window_size, self.window_size, C)
#
# KeyboardInterrupt:
